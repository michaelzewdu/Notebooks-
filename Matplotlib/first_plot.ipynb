# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
randNumber = np.random.rand(20)
randNumber
# Out:
# array([0.40316661, 0.90561918, 0.32961971, 0.36781521, 0.08992532,
#        0.09059624, 0.88551988, 0.1817429 , 0.6933286 , 0.11441047,
#        0.55537175, 0.59293428, 0.9896844 , 0.7025667 , 0.38993944,
#        0.79128228, 0.57356091, 0.67490494, 0.12605185, 0.04787938])

# %%
# Selecting the style of plot
style.use('ggplot')

# Plot the reandom numbers
plt.plot(randNumber,'g',label='line one', linewidth=2)

plt.xlabel('Range')

plt.ylabel('Numbers')
#title of the plot
plt.title('Mike\'s first plot')
# Out:
# Text(0.5, 1.0, "Mike's first plot")

# %%
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
